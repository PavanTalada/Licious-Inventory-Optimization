# %% [markdown]
# # Licious Exploratory Data Analysis\nAnalyzing the 'Freshness vs. Availability' trade-off.

# %%
import pandas as pd\nimport matplotlib.pyplot as plt\ndf = pd.read_csv('../data/licious_demand.csv')\ndf.groupby('Product')['Demand'].mean().plot(kind='bar', color='red')\nplt.title('Average Daily Demand by SKU')\nplt.show()
